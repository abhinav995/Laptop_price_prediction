# %%
import pandas as pd

df=pd.read_csv("cleaned_laptop_data.csv")
df
# Out:
#       Unnamed: 0 Company            TypeName  Inches                 Cpu  Ram  \
# 0              0   Apple           Ultrabook    13.3       Intel Core i5    8
# 1              1   Apple           Ultrabook    13.3       Intel Core i5    8
# 2              2      HP            Notebook    15.6       Intel Core i5    8
# 3              3   Apple           Ultrabook    15.4       Intel Core i7   16
# 4              4   Apple           Ultrabook    13.3       Intel Core i5    8
# ...          ...     ...                 ...     ...                 ...  ...
# 1268        1298  Lenovo  2 in 1 Convertible    14.0       Intel Core i7    4
# 1269        1299  Lenovo  2 in 1 Convertible    13.3       Intel Core i7   16
# 1270        1300  Lenovo            Notebook    14.0  Intel Celeron Dual    2
# 1271        1301      HP            Notebook    15.6       Intel Core i7    6
# 1272        1302    Asus            Notebook    15.6  Intel Celeron Dual    4
#
# ...

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches            Cpu  Ram  \
# 0           0   Apple  Ultrabook    13.3  Intel Core i5    8
# 1           1   Apple  Ultrabook    13.3  Intel Core i5    8
# 2           2      HP   Notebook    15.6  Intel Core i5    8
# 3           3   Apple  Ultrabook    15.4  Intel Core i7   16
# 4           4   Apple  Ultrabook    13.3  Intel Core i5    8
#
#                Memory1    Memory2                Gpu  OpSys   Price
# 0            128GB SSD  No memory    Intel Iris Plus  macOS   71379
# 1  128GB Flash Storage  No memory  Intel HD Graphics  macOS   47896
# 2            256GB SSD  No memory  Intel HD Graphics  No OS   30636
# 3            512GB SSD  No memory     AMD Radeon Pro  macOS  135195
# 4            256GB SSD  No memory    Intel Iris Plus  macOS   96096

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1273 entries, 0 to 1272
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1273 non-null   int64
#  1   Company     1273 non-null   object
#  2   TypeName    1273 non-null   object
#  3   Inches      1273 non-null   float64
#  4   Cpu         1273 non-null   object
#  5   Ram         1273 non-null   int64
#  6   Memory1     1273 non-null   object
#  7   Memory2     1273 non-null   object
#  8   Gpu         1273 non-null   object
#  9   OpSys       1273 non-null   object
#  10  Price       1273 non-null   int64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 109.5+ KB

# %%
df.isnull()
# Out:
#       Unnamed: 0  Company  TypeName  Inches    Cpu    Ram  Memory1  Memory2  \
# 0          False    False     False   False  False  False    False    False
# 1          False    False     False   False  False  False    False    False
# 2          False    False     False   False  False  False    False    False
# 3          False    False     False   False  False  False    False    False
# 4          False    False     False   False  False  False    False    False
# ...          ...      ...       ...     ...    ...    ...      ...      ...
# 1268       False    False     False   False  False  False    False    False
# 1269       False    False     False   False  False  False    False    False
# 1270       False    False     False   False  False  False    False    False
# 1271       False    False     False   False  False  False    False    False
# 1272       False    False     False   False  False  False    False    False
#
#         Gpu  OpSys  Price
# 0     False  False  False
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# Company       0
# TypeName      0
# Inches        0
# Cpu           0
# Ram           0
# Memory1       0
# Memory2       0
# Gpu           0
# OpSys         0
# Price         0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
l=LabelEncoder()

# %%
display(df.dtypes)
# Out:
# Unnamed: 0      int64
# Company        object
# TypeName       object
# Inches        float64
# Cpu            object
# Ram             int64
# Memory1        object
# Memory2        object
# Gpu            object
# OpSys          object
# Price           int64
# dtype: object

# %%
df["Inches"]=df["Inches"].astype("int")
display(df.dtypes)
# Out:
# Unnamed: 0     int64
# Company       object
# TypeName      object
# Inches         int32
# Cpu           object
# Ram            int64
# Memory1       object
# Memory2       object
# Gpu           object
# OpSys         object
# Price          int64
# dtype: object

# %%
df["Company"]=l.fit_transform(df["Company"])
df
# Out:
#       Unnamed: 0  Company            TypeName  Inches                 Cpu  \
# 0              0        1           Ultrabook      13       Intel Core i5
# 1              1        1           Ultrabook      13       Intel Core i5
# 2              2        7            Notebook      15       Intel Core i5
# 3              3        1           Ultrabook      15       Intel Core i7
# 4              4        1           Ultrabook      13       Intel Core i5
# ...          ...      ...                 ...     ...                 ...
# 1268        1298       10  2 in 1 Convertible      14       Intel Core i7
# 1269        1299       10  2 in 1 Convertible      13       Intel Core i7
# 1270        1300       10            Notebook      14  Intel Celeron Dual
# 1271        1301        7            Notebook      15       Intel Core i7
# 1272        1302        2            Notebook      15  Intel Celeron Dual
#
#       Ram              Memory1    Memory2                Gpu       OpSys  \
# ...

# %%
df["TypeName"]=l.fit_transform(df["TypeName"])
df["Cpu"]=l.fit_transform(df["Cpu"])
df["Memory1"]=l.fit_transform(df["Memory1"])
df["Memory2"]=l.fit_transform(df["Memory2"])
df["Gpu"]=l.fit_transform(df["Gpu"])
df["OpSys"]=l.fit_transform(df["OpSys"])
df
# Out:
#       Unnamed: 0  Company  TypeName  Inches  Cpu  Ram  Memory1  Memory2  Gpu  \
# 0              0        1         4      13   15    8        4        6   20
# 1              1        1         4      13   15    8        2        6   18
# 2              2        7         3      15   15    8       12        6   18
# 3              3        1         4      15   16   16       20        6    8
# 4              4        1         4      13   15    8       12        6   20
# ...          ...      ...       ...     ...  ...  ...      ...      ...  ...
# 1268        1298       10         0      14   16    4        4        6   18
# 1269        1299       10         0      13   16   16       20        6   18
# 1270        1300       10         3      14   11    2       21        6   18
# 1271        1301        7         3      15   16    6        8        6   12
# 1272        1302        2         3      15   11    4       17        6   18
#
#       OpSys   Price
# 0         8   71379
# ...

# %%
list(df.columns)
# Out:
# ['Company',
#  'TypeName',
#  'Inches',
#  'Cpu',
#  'Ram',
#  'Memory1',
#  'Memory2',
#  'Gpu',
#  'OpSys',
#  'Price']

# %%
x=df.drop(columns="Price")
x
# Out:
#       Company  TypeName  Inches  Cpu  Ram  Memory1  Memory2  Gpu  OpSys
# 0           1         4      13   15    8        4        6   20      8
# 1           1         4      13   15    8        2        6   18      8
# 2           7         3      15   15    8       12        6   18      4
# 3           1         4      15   16   16       20        6    8      8
# 4           1         4      13   15    8       12        6   20      8
# ...       ...       ...     ...  ...  ...      ...      ...  ...    ...
# 1268       10         0      14   16    4        4        6   18      5
# 1269       10         0      13   16   16       20        6   18      5
# 1270       10         3      14   11    2       21        6   18      5
# 1271        7         3      15   16    6        8        6   12      5
# 1272        2         3      15   11    4       17        6   18      5
#
# [1273 rows x 9 columns]

# %%
y=df.Price
y
# Out:
# 0        71379
# 1        47896
# 2        30636
# 3       135195
# 4        96096
#          ...
# 1268     33993
# 1269     79867
# 1270     12201
# 1271     40706
# 1272     19660
# Name: Price, Length: 1273, dtype: int64

# %%
print(x)
# Out:
#       Company  TypeName  Inches  Cpu  Ram  Memory1  Memory2  Gpu  OpSys
# 0           1         4      13   15    8        4        6   20      8
# 1           1         4      13   15    8        2        6   18      8
# 2           7         3      15   15    8       12        6   18      4
# 3           1         4      15   16   16       20        6    8      8
# 4           1         4      13   15    8       12        6   20      8
# ...       ...       ...     ...  ...  ...      ...      ...  ...    ...
# 1268       10         0      14   16    4        4        6   18      5
# 1269       10         0      13   16   16       20        6   18      5
# 1270       10         3      14   11    2       21        6   18      5
# 1271        7         3      15   16    6        8        6   12      5
# 1272        2         3      15   11    4       17        6   18      5
#
# [1273 rows x 9 columns]

# %%
print(y)
# Out:
# 0        71379
# 1        47896
# 2        30636
# 3       135195
# 4        96096
#          ...
# 1268     33993
# 1269     79867
# 1270     12201
# 1271     40706
# 1272     19660
# Name: Price, Length: 1273, dtype: int64

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2)

# %%
print(xtrain)
# Out:
#       Company  TypeName  Inches  Cpu  Ram  Memory1  Memory2  Gpu  OpSys
# 225         4         3      14   15    8       12        6   18      5
# 1187        0         3      17   14    4        8        6   31      5
# 609         5         3      15   15    8       12        6   18      5
# 636         4         4      13   15    8       12        6   22      5
# 798        10         3      15   14    4       17        6   18      5
# ...       ...       ...     ...  ...  ...      ...      ...  ...    ...
# 1133       11         1      14   16   16       12        1   34      5
# 810         2         3      15   15    4        8        6   25      2
# 534        10         3      14   15    4       17        6   18      5
# 773        10         0      14   15    8       12        6   18      5
# 316        10         3      14   11    4       14        6   18      5
#
# [1018 rows x 9 columns]

# %%
print(xtest)
# Out:
#      Company  TypeName  Inches  Cpu  Ram  Memory1  Memory2  Gpu  OpSys
# 896        4         1      15   16   16        4        1   34      5
# 960        7         3      15   15    8        8        6   18      5
# 532        2         3      15    6    4       17        6    9      5
# 915        7         1      17   15    8        4        1   34      5
# 655       10         0      13   15    8       12        6   18      5
# ..       ...       ...     ...  ...  ...      ...      ...  ...    ...
# 229        2         3      15    0    4        4        1   12      5
# 919       10         0      11   13    8       12        6   18      5
# 925        7         5      15   16    8       23        6   41      5
# 549       10         3      15   14    4        4        6   18      5
# 160        0         3      15   18    4        8        6   18      5
#
# [255 rows x 9 columns]

# %%
print(ytest)
# Out:
# 896     71875
# 960     42944
# 532     18595
# 915     74539
# 655     55092
#         ...
# 229     30636
# 919     69211
# 925    119827
# 549     33566
# 160     19368
# Name: Price, Length: 255, dtype: int64

# %%
print(ytrain)
# Out:
# 225      45768
# 1187     31861
# 609      42571
# 636      77251
# 798      26102
#          ...
# 1133     94252
# 810      27652
# 534      41825
# 773     124142
# 316      15558
# Name: Price, Length: 1018, dtype: int64

# %%
xtrain.shape
# Out:
# (1018, 9)

# %%
xtest.shape
# Out:
# (255, 9)

# %%
ytrain.shape
# Out:
# (1018,)

# %%
ytest.shape
# Out:
# (255,)

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(xtrain,ytrain)
# Out:
# c:\Users\ABHINAV\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
model.predict(xtest)
# Out:
# array([ 58555,  24456,  10603,  53227,  63883,  38841,  27120,  71875,
#         32661,  24808,  26054,  31915,  20726,  43636,  21258,  13267,
#        101232,  32980,  29784,  19128, 104962, 168045,  21258,  79867,
#         72940, 113753, 125155,  62071,  58075,  35644,  53227,  89864,
#         15398,  43636,  23976,  95851,  38788,  35112,  37243,  92615,
#         69530,  56503,  45821,  13267,  69530,  58555,  26587,  58555,
#         94252,  26102,  20726,  75924,  95851,  26587,  35325,  24456,
#         53227,  68145,  95851,  58555,  81785,  35644,  95851, 104908,
#        133147, 159787,  26587,  53227,  42624,  95851,  95851,  31915,
#         63883,  88178,  80908,  53227,  21259,  95851,  62284,  63670,
#         81785,  24988,  95851, 122491,  48432,  72940,  81785,  62231,
#         81785,  39907,  15931,  89864, 107258,  33993, 103097,  46833,
#         24456,  44808,  24988,  63499,  71875,  31915, 107258, 128671,
# ...

# %%
print(ytest)
# Out:
# 896     71875
# 960     42944
# 532     18595
# 915     74539
# 655     55092
#         ...
# 229     30636
# 919     69211
# 925    119827
# 549     33566
# 160     19368
# Name: Price, Length: 255, dtype: int64

# %%
model.score(xtest,ytest)
# Out:
# 0.01568627450980392

# %%
from sklearn.ensemble import RandomForestClassifier
model1=RandomForestClassifier()
model1.fit(xtrain,ytrain)
# Out:
# RandomForestClassifier()

# %%
model1.predict(xtrain)
# Out:
# array([68184, 31861, 42571, ..., 41825, 87219, 15558], dtype=int64)

# %%
model1.score(xtest,ytest)
# Out:
# 0.03529411764705882

# %%
from sklearn.tree import DecisionTreeClassifier
model2=DecisionTreeClassifier()
model2.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier()

# %%
model2.predict(xtrain)
# Out:
# array([45768, 31861, 42571, ..., 41825, 53227, 15558], dtype=int64)

# %%
model2.score(xtest,ytest)
# Out:
# 0.03137254901960784

# %%
import pickle
f=pickle.dump(model1,open("laptop_prediction.pkl","wb"))
